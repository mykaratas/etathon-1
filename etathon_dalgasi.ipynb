# %%
import pandas as pd
import numpy as np
import time
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("etathon.xlsx")

# %%
data
# Out:
#        MusteriAdi  SiparisNo       SiparisGirisTarihi SiparisGirisSaati  \
# 0       Customer1   60076375  2999-07-30 00:00:00.000  18:00:38.6015147
# 1       Customer1   60076375  2999-07-30 00:00:00.000  18:00:38.5391146
# 2       Customer1   60076368  2999-07-30 00:00:00.000  17:45:09.4170827
# 3       Customer2   60067441  2999-07-06 00:00:00.000  17:15:31.6426846
# 4       Customer2   60070813  2999-07-16 00:00:00.000  20:57:56.2469756
# ...           ...        ...                      ...               ...
# 8319  Customer120   60068721  2999-07-10 00:00:00.000  18:01:04.6232991
# 8320   Customer14   60073554  2999-07-23 00:00:00.000  16:44:22.1870783
# 8321   Customer54   60073152  2999-07-23 00:00:00.000  09:02:13.9807763
# 8322  Customer219   60072925  2999-07-21 00:00:00.000  09:05:35.9179298
# 8323   Customer24   60067333  2999-07-06 00:00:00.000  14:44:18.8539491
#
#        TalepEdilenSeferTarihi     EnErkenYuklemeTarihi  \
# ...

# %%
data=data.drop(['SiparisGirisSaati','TalepEdilenSeferTarihi','EnErkenYuklemeTarihi','EnGecYuklemeTarihi','TalepEdilenSeferSaati','SeferTarihi','TalepEdilenDorseTipi','TalepEdilenZeminTipi','UgrakSayisi','SevkiyatNoktasiAdi','CikisNoktasi','VarisNoktasi','YukCinsi'],axis=1)

# %%
data
# Out:
#        MusteriAdi  SiparisNo       SiparisGirisTarihi TalepEdilenAracTipi  \
# 0       Customer1   60076375  2999-07-30 00:00:00.000                 Tır
# 1       Customer1   60076375  2999-07-30 00:00:00.000                 Tır
# 2       Customer1   60076368  2999-07-30 00:00:00.000                 Tır
# 3       Customer2   60067441  2999-07-06 00:00:00.000              Kamyon
# 4       Customer2   60070813  2999-07-16 00:00:00.000              Kamyon
# ...           ...        ...                      ...                 ...
# 8319  Customer120   60068721  2999-07-10 00:00:00.000                 NaN
# 8320   Customer14   60073554  2999-07-23 00:00:00.000              Kamyon
# 8321   Customer54   60073152  2999-07-23 00:00:00.000              Kamyon
# 8322  Customer219   60072925  2999-07-21 00:00:00.000              Kamyon
# 8323   Customer24   60067333  2999-07-06 00:00:00.000                 Tır
#
#         Tonaj  PlanKm
# 0     26000.0      54
# 1     26000.0    1240
# ...

# %%
data.describe().T
# Out:
#             count          mean          std         min          25%  \
# SiparisNo  8324.0  6.007114e+07  3407.295694  60065124.0  60068157.75
# Tonaj      8324.0  1.545266e+04  8745.819380        50.0      9000.00
# PlanKm     8324.0  3.403985e+02   351.628291         1.0        78.00
#
#                   50%         75%         max
# SiparisNo  60071189.0  60074056.0  60077647.0
# Tonaj         15000.0     23000.0     27000.0
# PlanKm          199.5       516.0      3077.0

# %%
data.isnull().sum()
# Out:
# MusteriAdi               0
# SiparisNo                0
# SiparisGirisTarihi       0
# TalepEdilenAracTipi    472
# Tonaj                    0
# PlanKm                   0
# dtype: int64

# %%
missing_value_ratio = ((data.isnull().sum()/data.shape[0]))
print(missing_value_ratio)
# Out:
# MusteriAdi             0.000000
# SiparisNo              0.000000
# SiparisGirisTarihi     0.000000
# TalepEdilenAracTipi    0.056704
# Tonaj                  0.000000
# PlanKm                 0.000000
# dtype: float64

# %%
data
# Out:
#        MusteriAdi  SiparisNo       SiparisGirisTarihi TalepEdilenAracTipi  \
# 0       Customer1   60076375  2999-07-30 00:00:00.000                 Tır
# 1       Customer1   60076375  2999-07-30 00:00:00.000                 Tır
# 2       Customer1   60076368  2999-07-30 00:00:00.000                 Tır
# 3       Customer2   60067441  2999-07-06 00:00:00.000              Kamyon
# 4       Customer2   60070813  2999-07-16 00:00:00.000              Kamyon
# ...           ...        ...                      ...                 ...
# 8319  Customer120   60068721  2999-07-10 00:00:00.000                 NaN
# 8320   Customer14   60073554  2999-07-23 00:00:00.000              Kamyon
# 8321   Customer54   60073152  2999-07-23 00:00:00.000              Kamyon
# 8322  Customer219   60072925  2999-07-21 00:00:00.000              Kamyon
# 8323   Customer24   60067333  2999-07-06 00:00:00.000                 Tır
#
#         Tonaj  PlanKm
# 0     26000.0      54
# 1     26000.0    1240
# ...

# %%
data.isnull().sum()
# Out:
# MusteriAdi               0
# SiparisNo                0
# SiparisGirisTarihi       0
# TalepEdilenAracTipi    472
# Tonaj                    0
# PlanKm                   0
# dtype: int64

# %%
kelime=data['SiparisGirisTarihi']

# %%
for i in range(len(kelime)):
    kelime[i]=str(kelime[i][:10])
    kelime[i]=kelime[i].replace("2999","2018")
# Out:
# C:\Users\ulti\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ulti\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
kelime
# Out:
# 0       2018-07-30
# 1       2018-07-30
# 2       2018-07-30
# 3       2018-07-06
# 4       2018-07-16
#            ...
# 8319    2018-07-10
# 8320    2018-07-23
# 8321    2018-07-23
# 8322    2018-07-21
# 8323    2018-07-06
# Name: SiparisGirisTarihi, Length: 8324, dtype: object

# %%
#data["SiparisGirisTarihi_new"] = kelime

# %%
data
# Out:
#        MusteriAdi  SiparisNo SiparisGirisTarihi TalepEdilenAracTipi    Tonaj  \
# 0       Customer1   60076375         2018-07-30                 Tır  26000.0
# 1       Customer1   60076375         2018-07-30                 Tır  26000.0
# 2       Customer1   60076368         2018-07-30                 Tır  26000.0
# 3       Customer2   60067441         2018-07-06              Kamyon   3000.0
# 4       Customer2   60070813         2018-07-16              Kamyon  15000.0
# ...           ...        ...                ...                 ...      ...
# 8319  Customer120   60068721         2018-07-10                 NaN   1873.0
# 8320   Customer14   60073554         2018-07-23              Kamyon  15000.0
# 8321   Customer54   60073152         2018-07-23              Kamyon  12000.0
# 8322  Customer219   60072925         2018-07-21              Kamyon  15000.0
# 8323   Customer24   60067333         2018-07-06                 Tır  26000.0
#
#       PlanKm
# 0         54
# 1       1240
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8324 entries, 0 to 8323
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MusteriAdi           8324 non-null   object
#  1   SiparisNo            8324 non-null   int64
#  2   SiparisGirisTarihi   8324 non-null   object
#  3   TalepEdilenAracTipi  7852 non-null   object
#  4   Tonaj                8324 non-null   float64
#  5   PlanKm               8324 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 390.3+ KB

# %%
date1 = '2018-07-01'
date2 = '2018-07-07'

date3= '2018-07-08'
date4= '2018-07-14'

date5= '2018-07-15'
date6= '2018-07-21'

date7= '2018-07-22'
date8= '2018-07-28'

date9= '2018-07-29'
date10= '2018-08-04'

hafta1 = pd.date_range(date1, date2).tolist()
hafta2 = pd.date_range(date3, date4).tolist()
hafta3 = pd.date_range(date5, date6).tolist()
hafta4 = pd.date_range(date7, date8).tolist()
hafta5 = pd.date_range(date9, date10).tolist()




#if data[0]["SiparisGirisTarihi"] in mtdates:
#   hafta1=data[0]

# %%
hafta1
# Out:
# [Timestamp('2018-07-01 00:00:00', freq='D'),
#  Timestamp('2018-07-02 00:00:00', freq='D'),
#  Timestamp('2018-07-03 00:00:00', freq='D'),
#  Timestamp('2018-07-04 00:00:00', freq='D'),
#  Timestamp('2018-07-05 00:00:00', freq='D'),
#  Timestamp('2018-07-06 00:00:00', freq='D'),
#  Timestamp('2018-07-07 00:00:00', freq='D')]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8324 entries, 0 to 8323
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MusteriAdi           8324 non-null   object
#  1   SiparisNo            8324 non-null   int64
#  2   SiparisGirisTarihi   8324 non-null   object
#  3   TalepEdilenAracTipi  7852 non-null   object
#  4   Tonaj                8324 non-null   float64
#  5   PlanKm               8324 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 390.3+ KB

# %%
data.dropna(subset=['TalepEdilenAracTipi'], inplace=True)
data=data.reset_index()

# %%
data["SiparisGirisTarihi"][0] in hafta4
# Out:
# False

# %%
data["SiparisGirisTarihi"]=pd.to_datetime(data["SiparisGirisTarihi"],format="%Y-%m-%d")

# %%
data
# Out:
#       index   MusteriAdi  SiparisNo SiparisGirisTarihi TalepEdilenAracTipi  \
# 0         0    Customer1   60076375         2018-07-30                 Tır
# 1         1    Customer1   60076375         2018-07-30                 Tır
# 2         2    Customer1   60076368         2018-07-30                 Tır
# 3         3    Customer2   60067441         2018-07-06              Kamyon
# 4         4    Customer2   60070813         2018-07-16              Kamyon
# ...     ...          ...        ...                ...                 ...
# 7847   8318   Customer53   60072521         2018-07-20              Kamyon
# 7848   8320   Customer14   60073554         2018-07-23              Kamyon
# 7849   8321   Customer54   60073152         2018-07-23              Kamyon
# 7850   8322  Customer219   60072925         2018-07-21              Kamyon
# 7851   8323   Customer24   60067333         2018-07-06                 Tır
#
#         Tonaj  PlanKm
# 0     26000.0      54
# ...

# %%
tablo1=[]
tablo2=[]
tablo3=[]
tablo4=[]
tablo5=[]

# %%
tablo1
# Out:
# []

# %%
for i in range(len(data)):
    if data["SiparisGirisTarihi"][i] in hafta1:
        tablo1.append(data.iloc[i])
    if data["SiparisGirisTarihi"][i] in hafta2:
        tablo2.append(data.iloc[i])
    if data["SiparisGirisTarihi"][i] in hafta3:
        tablo3.append(data.iloc[i])
    if data["SiparisGirisTarihi"][i] in hafta4:
        tablo4.append(data.iloc[i])
    if data["SiparisGirisTarihi"][i] in hafta5:
        tablo5.append(data.iloc[i])

# %%
Tablo1=pd.DataFrame(tablo1)
Tablo2=pd.DataFrame(tablo2)
Tablo3=pd.DataFrame(tablo3)
Tablo4=pd.DataFrame(tablo4)
Tablo5=pd.DataFrame(tablo5)

# %%
Tablo5
# Out:
#       index   MusteriAdi  SiparisNo SiparisGirisTarihi TalepEdilenAracTipi  \
# 0         0    Customer1   60076375         2018-07-30                 Tır
# 1         1    Customer1   60076375         2018-07-30                 Tır
# 2         2    Customer1   60076368         2018-07-30                 Tır
# 10       10    Customer3   60076287         2018-07-30                 Tır
# 30       31    Customer8   60076925         2018-07-31              Kamyon
# ...     ...          ...        ...                ...                 ...
# 7770   8238   Customer71   60076835         2018-07-31                 Tır
# 7798   8268  Customer249   60075893         2018-07-30                 Tır
# 7815   8286    Customer2   60076043         2018-07-30              Kamyon
# 7817   8288    Customer2   60076749         2018-07-31              Kamyon
# 7838   8309   Customer71   60076707         2018-07-31              Kamyon
#
#         Tonaj  PlanKm
# 0     26000.0      54
# ...

# %%
Tablo1.describe().T
# Out:
#             count          mean          std         min         25%  \
# index      1687.0  4.108212e+03  2378.868963         3.0      2186.0
# SiparisNo  1687.0  6.006642e+07   764.659145  60065124.0  60065739.0
# Tonaj      1687.0  1.648903e+04  8312.318002      1000.0      9000.0
# PlanKm     1687.0  3.166378e+02   341.133203         7.0        69.5
#
#                   50%         75%         max
# index          4037.0      5985.5      8323.0
# SiparisNo  60066454.0  60067055.0  60068969.0
# Tonaj         18000.0     23000.0     27000.0
# PlanKm          180.0       488.0      3077.0

# %%
data.head()
# Out:
#    index MusteriAdi  SiparisNo SiparisGirisTarihi TalepEdilenAracTipi  \
# 0      0  Customer1   60076375         2018-07-30                 Tır
# 1      1  Customer1   60076375         2018-07-30                 Tır
# 2      2  Customer1   60076368         2018-07-30                 Tır
# 3      3  Customer2   60067441         2018-07-06              Kamyon
# 4      4  Customer2   60070813         2018-07-16              Kamyon
#
#      Tonaj  PlanKm
# 0  26000.0      54
# 1  26000.0    1240
# 2  26000.0    1183
# 3   3000.0     136
# 4  15000.0     982

# %%
Tablo1.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-46edae2e777b> in <module>
# ----> 1 Tablo1.type()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
a=pd.concat([Tablo1, Tablo2], axis=0)

# %%
a
# Out:
#       index  MusteriAdi  SiparisNo SiparisGirisTarihi TalepEdilenAracTipi  \
# 3         3   Customer2   60067441         2018-07-06              Kamyon
# 7         7   Customer1   60066417         2018-07-04                 Tır
# 11       11   Customer3   60065372         2018-07-02                 Tır
# 31       32   Customer7   60067185         2018-07-06                 Tır
# 37       39   Customer8   60066389         2018-07-04              Kamyon
# ...     ...         ...        ...                ...                 ...
# 7825   8296   Customer2   60069955         2018-07-13              Kamyon
# 7826   8297  Customer20   60070134         2018-07-14                 Tır
# 7828   8299  Customer20   60067814         2018-07-09                 Tır
# 7841   8312   Customer2   60068118         2018-07-09              Kamyon
# 7843   8314  Customer20   60069328         2018-07-12                 Tır
#
#         Tonaj  PlanKm
# 3      3000.0     136
# 7     26000.0      92
# ...

# %%
a=pd.concat([a, Tablo3], axis=0)

# %%
plt.figure(figsize=(12,5))
plt.title("Price Distirbution Graph")
ax = sns.distplot(Tablo1["Tonaj"], color = 'y')

# %%
dategroup=Tablo4.groupby('SiparisGirisTarihi').mean()
plt.figure(figsize=(12,5))
dategroup['Tonaj'].plot(x=data.SiparisGirisTarihi)
plt.title('Tonaj')
# Out:
# Text(0.5, 1.0, 'Tonaj')

# %%
a
# Out:
#       index   MusteriAdi  SiparisNo SiparisGirisTarihi TalepEdilenAracTipi  \
# 3         3    Customer2   60067441         2018-07-06              Kamyon
# 7         7    Customer1   60066417         2018-07-04                 Tır
# 11       11    Customer3   60065372         2018-07-02                 Tır
# 31       32    Customer7   60067185         2018-07-06                 Tır
# 37       39    Customer8   60066389         2018-07-04              Kamyon
# ...     ...          ...        ...                ...                 ...
# 7835   8306    Customer2   60073109         2018-07-21              Kamyon
# 7837   8308    Customer2   60071121         2018-07-17              Kamyon
# 7845   8316  Customer260   60071271         2018-07-17              Kamyon
# 7847   8318   Customer53   60072521         2018-07-20              Kamyon
# 7850   8322  Customer219   60072925         2018-07-21              Kamyon
#
#         Tonaj  PlanKm
# 3      3000.0     136
# ...

# %%
a=pd.concat([a, Tablo4], axis=0)

# %%
a=pd.concat([a, Tablo5], axis=0)

# %%
a=a.drop(['index'],axis=1)

# %%
a
# Out:
#        MusteriAdi  SiparisNo SiparisGirisTarihi TalepEdilenAracTipi    Tonaj  \
# 3       Customer2   60067441         2018-07-06              Kamyon   3000.0
# 7       Customer1   60066417         2018-07-04                 Tır  26000.0
# 11      Customer3   60065372         2018-07-02                 Tır  26000.0
# 31      Customer7   60067185         2018-07-06                 Tır  26000.0
# 37      Customer8   60066389         2018-07-04              Kamyon   3000.0
# ...           ...        ...                ...                 ...      ...
# 7770   Customer71   60076835         2018-07-31                 Tır  26000.0
# 7798  Customer249   60075893         2018-07-30                 Tır  25000.0
# 7815    Customer2   60076043         2018-07-30              Kamyon   1000.0
# 7817    Customer2   60076749         2018-07-31              Kamyon   1000.0
# 7838   Customer71   60076707         2018-07-31              Kamyon  15000.0
#
#       PlanKm
# 3        136
# 7         92
# ...

# %%
fig=plt.figure()



plt.subplot(2,3,1)
plt.title('1. Haftanın Görselleştirilmesi')
plt.plot(Tablo1['TalepEdilenAracTipi'],Tablo1['Tonaj'].sum())

plt.subplot(2,3,2)
plt.title('2. Haftanın Görselleştirilmesi')
plt.plot(Tablo2['TalepEdilenAracTipi'],Tablo2['Tonaj'].sum())

plt.subplot(2,3,3)
plt.title('3. Haftanın Görselleştirilmesi')
plt.plot(Tablo3['TalepEdilenAracTipi'],Tablo3['Tonaj'].sum())

plt.figure(2)
plt.subplot(2,3,4)
plt.title('4. Haftanın Görselleştirilmesi')
plt.plot(Tablo4['TalepEdilenAracTipi'],Tablo4['Tonaj'].sum())

plt.subplot(2,3,5)
plt.title('5. Haftanın Görselleştirilmesi')
plt.plot(Tablo5['TalepEdilenAracTipi'],Tablo5['Tonaj'].sum())

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-d3db0d273338> in <module>
#       5 plt.subplot(2,3,1)
#       6 plt.title('1. Haftanın Görselleştirilmesi')
# ----> 7 plt.plot(Tablo1['TalepEdilenAracTipi'],Tablo1['Tonaj'].sum())
#       8
#       9 plt.subplot(2,3,2)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
# ...

# %%
len(Tablo1.query("TalepEdilenAracTipi == 'Kamyon'"))

# %%
ortalama=Tablo1['Tonaj'].sum()

# %%
ortalama
# Out:
# 27817000.0

# %%
ortalama2=Tablo2['Tonaj'].sum()

# %%
ortalama2
# Out:
# 28000000.0

# %%
ortalama3=Tablo3['Tonaj'].sum()

# %%
ortalama3
# Out:
# 30770000.0

# %%
ortalama4=Tablo4['Tonaj'].sum()

# %%
ortalama4
# Out:
# 28104000.0

# %%
ortalama5=Tablo5['Tonaj'].sum()

# %%
ortalama5
# Out:
# 12703000.0

# %%
#sns.boxplot(x='MusteriAdi', y='Tonaj', data = Tablo1)
#plt.boxplot(x='TalepEdilenAracTipi', data = Tablo1)
plt.figure(num = None, figsize = (12,8), dpi =40, facecolor='w',edgecolor='k')
sns.boxplot(x='TalepEdilenAracTipi',y='Tonaj', data=Tablo1)

# %%
plt.figure(num = None, figsize = (12,8), dpi =40, facecolor='w',edgecolor='k')
sns.boxplot(x='TalepEdilenAracTipi',y='Tonaj', data=Tablo2)

# %%
plt.figure(num = None, figsize = (12,8), dpi =40, facecolor='w',edgecolor='k')
sns.boxplot(x='TalepEdilenAracTipi',y='Tonaj', data=Tablo3)

# %%
plt.figure(num = None, figsize = (12,8), dpi =40, facecolor='w',edgecolor='k')
sns.boxplot(x='TalepEdilenAracTipi',y='Tonaj', data=Tablo4)

# %%
plt.figure(num = None, figsize = (12,8), dpi = 40, facecolor='w',edgecolor='k')
sns.boxplot(x='TalepEdilenAracTipi',y='Tonaj', data=Tablo5)

# %%
dict.plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
plt.figure(figsize=(12,5))
plt.title("Price Distirbution Graph")
ax = sns.distplot(Tablo1["Tonaj"], color = 'y')
